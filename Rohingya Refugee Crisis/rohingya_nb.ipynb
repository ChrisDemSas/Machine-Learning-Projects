# %%
# Import libraries
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
import numpy as np
import seaborn as sns
import xgboost as xgb

# %%
# Load the dataset

dummy = pd.read_csv('dummy.csv')
dummy = dummy.drop(columns = ['Unnamed: 0'])

dummy.head()
# Out:
#    Bhasan Char  Illegal Activity  People Leaving  Myanmar Rights Views  \
# 0            0                 2               0                     0
# 1            3                 2               2                     0
# 2            0                 2               1                     1
# 3            0                 1               5                     0
# 4            0                 1               2                     1
#
#    Mental Health  Trust  Access to Help  Personal Support  Violence  \
# 0              4      1               0                 0         1
# 1              4      5               0                 0         1
# 2              3      0               0                 0         1
# 3              4      3               0                 1         0
# 4              2      5               0                 0         2
#
#    Camp Condition  ...  \
# 0               2  ...
# 1               0  ...
# 2               2  ...
# 3               2  ...
# 4               2  ...
#
#    Do you think that there are Rohingya families who have married their daughter off to Bangladeshi boys/men?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Do you personally know any Rohingya family who has married their daughter off to a Bangladeshi boy/man?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    How often do you talk with Rohingya people outside Bangladesh and Myanmar?  \
# 0                                                  0
# 1                                                  3
# 2                                                  3
# 3                                                  0
# 4                                                  0
#
#    How often do you talk with others (non-Rohingya people) outside Bangladesh and Myanmar?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    How afraid are you to leave your child unattended in the camp after it gets dark?  \
# 0                                                  0
# 1                                                  0
# 2                                                  3
# 3                                                  0
# 4                                                  2
#
#    Do you think that there are Rohingya families whose child has gone missing since they moved to Bangladesh?  \
# 0                                                  0
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#    Do you personally know any Rohingya families whose child has gone missing since they moved to this camp?  \
# 0                                                  1
# 1                                                  2
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    To what extent do you feel at home in the camp in Bangladesh now?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Where do you think you will be in six months from now?  \
# 0                                                  7
# 1                                                  3
# 2                                                  1
# 3                                                  3
# 4                                                  9
#
#    How do you feel about the future?
# 0                                  4
# 1                                  4
# 2                                  4
# 3                                  3
# 4                                  4
#
# [5 rows x 35 columns]

# %%
# Find the correlation between columns and how you feel about the future (Use Matthew's Correlation Coefficient)
from sklearn.metrics import matthews_corrcoef # For How do you feel about the future?

dummy_copy = dummy.copy() # Copy used for coefficient analysis only
# dummy_copy.drop(columns = ['How many betel nuts a day on average?', 'How many cigarettes a day on average?'])

# Analysis for the Matthew's Correlation Coefficient
coefficient = {"Questions": dummy_copy.columns}

# Get the correlation coefficients
for item in dummy_copy.columns:
  curr = dummy_copy[item] # Get the column
  curr = curr.to_numpy()
  coef_list = []

  for q in dummy_copy.columns:
    Y = dummy_copy[q].to_numpy()

    coef = matthews_corrcoef(curr, Y)
    coef_list.append(coef)

  coefficient[item] = coef_list

coefficient = pd.DataFrame(coefficient)

pd.set_option('display.max_rows', None)
coefficient.head(100)
# Out:
#                                             Questions  Bhasan Char  \
# 0                                         Bhasan Char     1.000000
# 1                                    Illegal Activity     0.113618
# 2                                      People Leaving     0.010490
# 3                                Myanmar Rights Views    -0.020695
# 4                                       Mental Health    -0.029834
# 5                                               Trust    -0.015812
# 6                                      Access to Help    -0.042969
# 7                                    Personal Support    -0.021230
# 8                                            Violence     0.009032
# 9                                      Camp Condition    -0.056695
# 10                                                Sex     0.027010
# 11  How satisfied are you with the level of hygien...    -0.024222
# 12  Do you think there are enough healthcare facil...    -0.008807
# 13  How satisfied are you with the quality of heal...     0.009869
# 14  Do you think you are able to exercise your rel...     0.007211
# 15  How satisfied are you with the number of relig...    -0.022750
# 16  Do you think there are enough educational oppo...     0.007211
# 17  Do you think there are enough educational oppo...     0.087246
# 18  Do you think there are enough educational oppo...     0.043202
# 19  How satisfied are you with the quality of educ...    -0.028188
# 20  How satisfied are you with the number of job o...     0.042068
# 21  How satisfied are you with the income your fam...     0.059474
# 22             How do you mostly hear about the news?     0.002645
# 23  Do you consider any Bangladeshis as your friends?     0.118535
# 24  Do you believe Rohingya and Bangladeshis can b...     0.019521
# 25  Do you think that there are Rohingya families ...     0.015516
# 26  Do you personally know any Rohingya family who...     0.061618
# 27  How often do you talk with Rohingya people out...    -0.041980
# 28  How often do you talk with others (non-Rohingy...    -0.009724
# 29  How afraid are you to leave your child unatten...     0.148203
# 30  Do you think that there are Rohingya families ...    -0.087578
# 31  Do you personally know any Rohingya families w...     0.062958
# 32  To what extent do you feel at home in the camp...    -0.073427
# 33  Where do you think you will be in six months f...    -0.025606
# 34                  How do you feel about the future?     0.031365
#
#     Illegal Activity  People Leaving  Myanmar Rights Views  Mental Health  \
# 0           0.113618        0.010490             -0.020695      -0.029834
# 1           1.000000        0.039194             -0.063248       0.012829
# 2           0.039194        1.000000             -0.017772       0.049450
# 3          -0.063248       -0.017772              1.000000       0.000734
# 4           0.012829        0.049450              0.000734       1.000000
# 5          -0.051846       -0.034784             -0.072003      -0.011726
# 6           0.001595        0.059652             -0.012592       0.048133
# 7          -0.075277       -0.090134              0.342238      -0.003941
# 8          -0.094778       -0.078468             -0.274760      -0.056425
# 9           0.068228        0.078879              0.047740       0.120513
# 10         -0.054038       -0.018017              0.075523      -0.206565
# 11         -0.049890        0.024774              0.000161       0.017213
# 12         -0.086357       -0.014091             -0.065371       0.015688
# 13          0.062684        0.012144             -0.022493      -0.011856
# 14          0.004472       -0.014903              0.027336      -0.040108
# 15          0.000784       -0.120952              0.001088       0.000088
# 16          0.004472        0.000880             -0.011813      -0.023483
# 17          0.046381       -0.001526             -0.013465      -0.007333
# 18          0.052204       -0.001392             -0.030879      -0.010201
# 19          0.021416        0.027101              0.001992      -0.006421
# 20          0.027847        0.114840             -0.083195      -0.046987
# 21         -0.012101       -0.112049             -0.135317      -0.004582
# 22         -0.003688        0.000404             -0.041435      -0.023847
# 23          0.027046        0.078760              0.352874      -0.058265
# 24         -0.107833       -0.035103              0.037226      -0.024554
# 25          0.154526        0.016401             -0.054578       0.004459
# 26          0.070994       -0.001078             -0.033493      -0.032340
# 27          0.037809        0.016126              0.050120       0.105710
# 28         -0.002585       -0.004024              0.023294      -0.000750
# 29          0.071107       -0.021342             -0.100012      -0.029626
# 30         -0.050363       -0.054278             -0.031495       0.013740
# 31         -0.019399        0.002494             -0.013847       0.010206
# 32         -0.065997        0.130553              0.196455       0.028856
# 33          0.012216        0.026175             -0.005572       0.051811
# 34          0.077229       -0.105627             -0.038637      -0.032848
#
#        Trust  Access to Help  Personal Support  Violence  ...  \
# 0  -0.015812       -0.042969         -0.021230  0.009032  ...
# 1  -0.051846        0.001595         -0.075277 -0.094778  ...
# 2  -0.034784        0.059652         -0.090134 -0.078468  ...
# 3  -0.072003       -0.012592          0.342238 -0.274760  ...
# 4  -0.011726        0.048133         -0.003941 -0.056425  ...
# 5   1.000000        0.036391         -0.013131  0.147105  ...
# 6   0.036391        1.000000         -0.057552  0.112426  ...
# 7  -0.013131       -0.057552          1.000000 -0.157979  ...
# 8   0.147105        0.112426         -0.157979  1.000000  ...
# 9  -0.021981        0.320481         -0.084891  0.056437  ...
# 10 -0.023657       -0.061511          0.064907  0.089049  ...
# 11  0.003845       -0.062223         -0.009276  0.025708  ...
# 12  0.018310        0.021340         -0.043720  0.042437  ...
# 13  0.033314        0.100420         -0.025730  0.052771  ...
# 14  0.027925        0.014823          0.019400  0.004296  ...
# 15 -0.025970       -0.057038          0.035079  0.016956  ...
# 16 -0.003114       -0.017839         -0.012368  0.004296  ...
# 17 -0.012547        0.002617         -0.024469 -0.007453  ...
# 18 -0.004898       -0.007953         -0.045797 -0.006801  ...
# 19  0.015528       -0.013584          0.010434  0.016821  ...
# 20  0.021010       -0.063176          0.025792  0.076512  ...
# 21 -0.008509       -0.153166         -0.041805  0.035713  ...
# 22  0.007889        0.081395          0.057747  0.094266  ...
# 23 -0.137971       -0.115182          0.143896 -0.307845  ...
# 24  0.009873        0.045861          0.030294 -0.001784  ...
# 25 -0.022597       -0.041174         -0.034033 -0.011002  ...
# 26 -0.008862       -0.024831         -0.004308 -0.005264  ...
# 27  0.005083        0.131648         -0.051776 -0.067748  ...
# 28  0.008227        0.002435          0.030947 -0.030034  ...
# 29  0.017681       -0.013457         -0.042640  0.056706  ...
# 30  0.004750        0.030033          0.011649  0.071869  ...
# 31  0.085746       -0.028075         -0.032275 -0.019577  ...
# 32 -0.028149        0.182250         -0.003564 -0.058160  ...
# 33 -0.005398        0.050387         -0.005101 -0.025778  ...
# 34 -0.037287       -0.158643         -0.118685 -0.045162  ...
#
#     Do you think that there are Rohingya families who have married their daughter off to Bangladeshi boys/men?  \
# 0                                            0.015516
# 1                                            0.154526
# 2                                            0.016401
# 3                                           -0.054578
# 4                                            0.004459
# 5                                           -0.022597
# 6                                           -0.041174
# 7                                           -0.034033
# 8                                           -0.011002
# 9                                            0.064909
# 10                                           0.029428
# 11                                           0.000091
# 12                                          -0.147564
# 13                                          -0.015157
# 14                                           0.004084
# 15                                           0.000447
# 16                                           0.004084
# 17                                          -0.007085
# 18                                          -0.006465
# 19                                           0.000971
# 20                                           0.002382
# 21                                           0.006755
# 22                                           0.011212
# 23                                           0.001845
# 24                                          -0.031415
# 25                                           1.000000
# 26                                           0.478464
# 27                                           0.002589
# 28                                          -0.004721
# 29                                           0.000770
# 30                                           0.029915
# 31                                           0.010397
# 32                                           0.005118
# 33                                           0.002872
# 34                                           0.006484
#
#     Do you personally know any Rohingya family who has married their daughter off to a Bangladeshi boy/man?  \
# 0                                            0.061618
# 1                                            0.070994
# 2                                           -0.001078
# 3                                           -0.033493
# 4                                           -0.032340
# 5                                           -0.008862
# 6                                           -0.024831
# 7                                           -0.004308
# 8                                           -0.005264
# 9                                            0.050987
# 10                                          -0.011198
# 11                                           0.000044
# 12                                          -0.105207
# 13                                           0.001229
# 14                                           0.001954
# 15                                           0.000214
# 16                                           0.001954
# 17                                          -0.003390
# 18                                          -0.003093
# 19                                           0.000464
# 20                                          -0.003427
# 21                                           0.017501
# 22                                           0.009083
# 23                                           0.013451
# 24                                           0.008162
# 25                                           0.478464
# 26                                           1.000000
# 27                                           0.003460
# 28                                          -0.002259
# 29                                           0.022636
# 30                                           0.014313
# 31                                           0.049336
# 32                                          -0.013660
# 33                                           0.001374
# 34                                          -0.003692
#
#     How often do you talk with Rohingya people outside Bangladesh and Myanmar?  \
# 0                                           -0.041980
# 1                                            0.037809
# 2                                            0.016126
# 3                                            0.050120
# 4                                            0.105710
# 5                                            0.005083
# 6                                            0.131648
# 7                                           -0.051776
# 8                                           -0.067748
# 9                                            0.160997
# 10                                          -0.251638
# 11                                           0.019909
# 12                                          -0.020198
# 13                                           0.094277
# 14                                           0.020742
# 15                                          -0.002861
# 16                                          -0.014607
# 17                                           0.004899
# 18                                          -0.010452
# 19                                           0.063995
# 20                                          -0.100074
# 21                                          -0.016502
# 22                                          -0.064783
# 23                                           0.026528
# 24                                           0.008471
# 25                                           0.002589
# 26                                           0.003460
# 27                                           1.000000
# 28                                           0.027181
# 29                                          -0.004362
# 30                                           0.015931
# 31                                           0.013974
# 32                                           0.128195
# 33                                           0.049076
# 34                                           0.002496
#
#     How often do you talk with others (non-Rohingya people) outside Bangladesh and Myanmar?  \
# 0                                           -0.009724
# 1                                           -0.002585
# 2                                           -0.004024
# 3                                            0.023294
# 4                                           -0.000750
# 5                                            0.008227
# 6                                            0.002435
# 7                                            0.030947
# 8                                           -0.030034
# 9                                           -0.028463
# 10                                          -0.015847
# 11                                          -0.009277
# 12                                          -0.112518
# 13                                           0.000870
# 14                                           0.001844
# 15                                          -0.010478
# 16                                           0.001844
# 17                                          -0.003198
# 18                                          -0.002918
# 19                                           0.000511
# 20                                           0.016121
# 21                                           0.024697
# 22                                          -0.016194
# 23                                           0.020397
# 24                                           0.007700
# 25                                          -0.004721
# 26                                          -0.002259
# 27                                           0.027181
# 28                                           1.000000
# 29                                          -0.004776
# 30                                          -0.114985
# 31                                           0.070598
# 32                                           0.017208
# 33                                           0.001987
# 34                                          -0.002870
#
#     How afraid are you to leave your child unattended in the camp after it gets dark?  \
# 0                                            0.148203
# 1                                            0.071107
# 2                                           -0.021342
# 3                                           -0.100012
# 4                                           -0.029626
# 5                                            0.017681
# 6                                           -0.013457
# 7                                           -0.042640
# 8                                            0.056706
# 9                                            0.015130
# 10                                          -0.062226
# 11                                          -0.002328
# 12                                          -0.005934
# 13                                           0.002052
# 14                                          -0.010037
# 15                                           0.001822
# 16                                          -0.035351
# 17                                           0.032051
# 18                                           0.007874
# 19                                          -0.023949
# 20                                           0.032602
# 21                                           0.118667
# 22                                          -0.054412
# 23                                          -0.076165
# 24                                          -0.035702
# 25                                           0.000770
# 26                                           0.022636
# 27                                          -0.004362
# 28                                          -0.004776
# 29                                           1.000000
# 30                                          -0.071644
# 31                                           0.062041
# 32                                          -0.035098
# 33                                           0.010606
# 34                                           0.026574
#
#     Do you think that there are Rohingya families whose child has gone missing since they moved to Bangladesh?  \
# 0                                           -0.087578
# 1                                           -0.050363
# 2                                           -0.054278
# 3                                           -0.031495
# 4                                            0.013740
# 5                                            0.004750
# 6                                            0.030033
# 7                                            0.011649
# 8                                            0.071869
# 9                                            0.133266
# 10                                           0.046109
# 11                                          -0.000261
# 12                                           0.221488
# 13                                           0.002640
# 14                                          -0.011682
# 15                                           0.008459
# 16                                          -0.011682
# 17                                          -0.022586
# 18                                          -0.028431
# 19                                          -0.002777
# 20                                          -0.030600
# 21                                          -0.037417
# 22                                           0.027432
# 23                                          -0.216564
# 24                                          -0.030586
# 25                                           0.029915
# 26                                           0.014313
# 27                                           0.015931
# 28                                          -0.114985
# 29                                          -0.071644
# 30                                           1.000000
# 31                                          -0.456868
# 32                                           0.008498
# 33                                          -0.008216
# 34                                           0.008738
#
#     Do you personally know any Rohingya families whose child has gone missing since they moved to this camp?  \
# 0                                            0.062958
# 1                                           -0.019399
# 2                                            0.002494
# 3                                           -0.013847
# 4                                            0.010206
# 5                                            0.085746
# 6                                           -0.028075
# 7                                           -0.032275
# 8                                           -0.019577
# 9                                           -0.134689
# 10                                          -0.097740
# 11                                           0.055214
# 12                                          -0.120331
# 13                                          -0.032241
# 14                                          -0.063801
# 15                                          -0.008891
# 16                                           0.006802
# 17                                           0.008614
# 18                                           0.011586
# 19                                           0.001231
# 20                                          -0.007963
# 21                                           0.059937
# 22                                          -0.032034
# 23                                           0.115438
# 24                                           0.002389
# 25                                           0.010397
# 26                                           0.049336
# 27                                           0.013974
# 28                                           0.070598
# 29                                           0.062041
# 30                                          -0.456868
# 31                                           1.000000
# 32                                          -0.028827
# 33                                           0.019833
# 34                                          -0.003346
#
#     To what extent do you feel at home in the camp in Bangladesh now?  \
# 0                                           -0.073427
# 1                                           -0.065997
# 2                                            0.130553
# 3                                            0.196455
# 4                                            0.028856
# 5                                           -0.028149
# 6                                            0.182250
# 7                                           -0.003564
# 8                                           -0.058160
# 9                                            0.296748
# 10                                           0.217858
# 11                                           0.022565
# 12                                          -0.039175
# 13                                           0.017946
# 14                                           0.023358
# 15                                          -0.000185
# 16                                           0.005045
# 17                                          -0.019342
# 18                                          -0.025380
# 19                                          -0.021963
# 20                                          -0.078628
# 21                                          -0.238295
# 22                                          -0.002568
# 23                                          -0.076213
# 24                                          -0.059917
# 25                                           0.005118
# 26                                          -0.013660
# 27                                           0.128195
# 28                                           0.017208
# 29                                          -0.035098
# 30                                           0.008498
# 31                                          -0.028827
# 32                                           1.000000
# 33                                           0.031461
# 34                                          -0.181678
#
#     Where do you think you will be in six months from now?  \
# 0                                           -0.025606
# 1                                            0.012216
# 2                                            0.026175
# 3                                           -0.005572
# 4                                            0.051811
# 5                                           -0.005398
# 6                                            0.050387
# 7                                           -0.005101
# 8                                           -0.025778
# 9                                            0.055782
# 10                                          -0.041195
# 11                                           0.087335
# 12                                          -0.004163
# 13                                          -0.039515
# 14                                          -0.001122
# 15                                          -0.044266
# 16                                          -0.001122
# 17                                           0.001946
# 18                                           0.001776
# 19                                          -0.043323
# 20                                          -0.028672
# 21                                          -0.038343
# 22                                          -0.005550
# 23                                           0.020717
# 24                                           0.000898
# 25                                           0.002872
# 26                                           0.001374
# 27                                           0.049076
# 28                                           0.001987
# 29                                           0.010606
# 30                                          -0.008216
# 31                                           0.019833
# 32                                           0.031461
# 33                                           1.000000
# 34                                          -0.194289
#
#     How do you feel about the future?
# 0                            0.031365
# 1                            0.077229
# 2                           -0.105627
# 3                           -0.038637
# 4                           -0.032848
# 5                           -0.037287
# 6                           -0.158643
# 7                           -0.118685
# 8                           -0.045162
# 9                           -0.131278
# 10                          -0.113786
# 11                          -0.065011
# 12                           0.001274
# 13                           0.011082
# 14                           0.003013
# 15                           0.282943
# 16                           0.003013
# 17                          -0.005228
# 18                          -0.004770
# 19                           0.110117
# 20                          -0.064821
# 21                           0.156091
# 22                          -0.074744
# 23                          -0.048367
# 24                          -0.000698
# 25                           0.006484
# 26                          -0.003692
# 27                           0.002496
# 28                          -0.002870
# 29                           0.026574
# 30                           0.008738
# 31                          -0.003346
# 32                          -0.181678
# 33                          -0.194289
# 34                           1.000000
#
# [35 rows x 36 columns]

# %%
# Correlation matrix is too large

def view_correlation(coef, index: int) -> int:
  """Take in an index and then return the sorted numbers."""

  df = coef.iloc[:, [0, index]]
  column = coef.columns[index]
  df = df.sort_values(column, ascending = False)

  return df

def obtain_features(coef, cut_off = 0.15) -> list:
  """Obtain the features after viewing correlation in list format.
  """

  features = []

  for item in coef.to_dict('records'):
    correlation = item[coef.columns[-1]]
    curr_index = coef.columns[0]
    question = item[curr_index]

    if np.abs(correlation) >= cut_off:
      features.append(question)

  return features

def create_features(curr: list, features: list) -> list:
  """Take in a current and features list and then append items from features to current, and then return them."""

  for item in features:
    if not (item in curr):
      curr.append(item)

  return curr

# View the correlation: How do you feel about the future?

curr = view_correlation(coefficient, 35)
future_features = obtain_features(curr)

# View the correlation: To what extent do you feel at home in the camp in Bangladesh now?

curr = view_correlation(coefficient, 33)
home_features = obtain_features(curr)

# View the correlation: Do you often feel stressed or overwhelmed by your situation?

#curr = view_correlation(coefficient, 31)
#stress_features = obtain_features(curr)

# Final list of features

features = create_features(future_features, home_features)
#features = create_features(features, stress_features)

# Final Dummy List
dummy['confidence_index'] = dummy['How do you feel about the future?'] + dummy['To what extent do you feel at home in the camp in Bangladesh now?']
dummy = dummy.drop(columns= ['How do you feel about the future?', 'To what extent do you feel at home in the camp in Bangladesh now?'])

# %%
# List the features
dummy = dummy.filter(items = ['confidence_index', *features])
dummy_feat = dummy.columns
print(f'Number of features: {len(dummy_feat)}')

for item in dummy_feat:
  print(item)
# Out:
# Number of features: 8
# confidence_index
# How satisfied are you with the number of religious facilities (like madrasas, mosques) in the camp?
# How satisfied are you with the income your family makes in the camp?
# Access to Help
# Where do you think you will be in six months from now?
# Camp Condition
# Sex
# Myanmar Rights Views

# %%
# Visualize the distribution of the confidence index

counts = pd.DataFrame(dummy['confidence_index'].value_counts())
counts.plot.bar()
# Out:
# <Axes: >

# %%
from matplotlib.font_manager import X11FontDirectories
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB, MultinomialNB

Y = dummy['confidence_index']
X = dummy.drop(['confidence_index'], axis = 1)


# Train Test Split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.20, random_state = 0)
X_val, X_test, Y_val, Y_test = train_test_split(X_test, Y_test, test_size = 0.5, random_state = 0)

# %%
# Fit the Gaussian Naive Bayes

NaiveBayes = MultinomialNB(alpha = 1)
model = NaiveBayes.fit(X_train, Y_train)
y_train_pred = NaiveBayes.predict(X_train)
y_val_pred = NaiveBayes.predict(X_val)
y_test_pred = NaiveBayes.predict(X_test)

  # Calculate Accuracy
train_acc = accuracy_score(Y_train, y_train_pred)
val_acc = accuracy_score(Y_val, y_val_pred)
test_acc = accuracy_score(Y_test, y_test_pred)

print(f"The Training Accuracy: {train_acc}")
print(f"The Validation Accuracy: {val_acc}")
print(f"The Test Accuracy: {test_acc}")
# Out:
# The Training Accuracy: 0.5906374501992032
# The Validation Accuracy: 0.5873015873015873
# The Test Accuracy: 0.6428571428571429

# %%
from sklearn.metrics import confusion_matrix, classification_report

report = pd.DataFrame(classification_report(Y_test, y_test_pred, output_dict = True))
report.head(100)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                    1    2     3          4          5    6  accuracy  \
# precision   0.629630  0.0   0.0   0.651163   1.000000  0.0  0.642857
# recall      0.980769  0.0   0.0   0.736842   0.153846  0.0  0.642857
# f1-score    0.766917  0.0   0.0   0.691358   0.266667  0.0  0.642857
# support    52.000000  8.0  14.0  38.000000  13.000000  1.0  0.642857
#
#             macro avg  weighted avg
# precision    0.380132      0.559404
# recall       0.311910      0.642857
# f1-score     0.287490      0.552524
# support    126.000000    126.000000
